# %% [markdown]
# ### Import

# %%
import random
import pandas as pd
import time
import json
import yaml
from ultralytics import YOLO
from pathlib import Path

# %% [markdown]
# ### Yolo model parameters
#
# **EPOCHS**: The number of times the entire training dataset is passed through the model during training. More epochs can help the model learn better, but too many can lead to overfitting.
#
# **IMG_SIZE** (image size): The target size (usually width and height in pixels) to which all training and inference images are resized. Larger sizes can improve detection accuracy but use more memory and computation.
#
# **BATCH** (batch size): The number of images the model processes at once before updating its internal parameters. A larger batch size can speed up training (if you have enough GPU memory) but may require more resources.

# %%
DATASET_YAML = Path("../data/silver/")  # point to your dataset.yaml
BASE_MODEL = "yolov8n-cls.pt"
EPOCHS = 50
IMG_SIZE = 512
FRACTION = 1
BATCH = 16
DEVICE = "cpu"
PROJECT_PATH = Path("../runs/classify")

CLASSES = {
    "pizza": 76,
    "spaghetti_bolognese": 90,
    "spaghetti_carbonara": 91,
}

# %% [markdown]
# ### First run of the pre-trained model

# %%
model = YOLO(BASE_MODEL)
random.seed(42)
N = 8 
subset = []
for cls in CLASSES.keys():
    cls_dir = Path(DATASET_YAML) / "val" / cls
    all_imgs = list(cls_dir.glob("*.jpg"))
    if len(all_imgs) >= N:
        subset.extend(random.sample(all_imgs, N))
    else:
        subset.extend(all_imgs)
results = model.predict(source=subset, imgsz=IMG_SIZE, device=DEVICE, save=True, verbose=False, project=PROJECT_PATH, name="food101_base_model",exist_ok=True)
for r in results:
    fname = Path(r.path).name
    pred_class = r.names[r.probs.top1]
    conf = r.probs.top1conf.item()
    print(f"{fname}: {pred_class} ({conf:.2f})")
# Out:
# Results saved to /workspaces/marktguru-home-assignment/runs/base_model
# 002620_76_pizza.jpg: pizza (0.99)
# 002667_76_pizza.jpg: pizza (0.86)
# 002673_76_pizza.jpg: pizza (1.00)
# 002610_76_pizza.jpg: pizza (0.72)
# 002675_76_pizza.jpg: pizza (0.96)
# 002650_76_pizza.jpg: pizza (0.98)
# 002577_76_pizza.jpg: pizza (0.96)
# 002504_76_pizza.jpg: pizza (0.99)
# 025088_90_spaghetti_bolognese.jpg: crayfish (0.91)
# 025101_90_spaghetti_bolognese.jpg: carbonara (0.38)
# 025187_90_spaghetti_bolognese.jpg: carbonara (0.80)
# 025023_90_spaghetti_bolognese.jpg: plate (0.68)
# 025036_90_spaghetti_bolognese.jpg: plate (0.29)
# 025201_90_spaghetti_bolognese.jpg: carbonara (1.00)
# 025011_90_spaghetti_bolognese.jpg: carbonara (1.00)
# 025068_90_spaghetti_bolognese.jpg: plate (0.50)
# 022289_91_spaghetti_carbonara.jpg: carbonara (0.95)
# 022254_91_spaghetti_carbonara.jpg: carbonara (1.00)
# 022257_91_spaghetti_carbonara.jpg: carbonara (0.99)
# 022410_91_spaghetti_carbonara.jpg: carbonara (1.00)
# 022473_91_spaghetti_carbonara.jpg: carbonara (1.00)
# 022450_91_spaghetti_carbonara.jpg: carbonara (0.98)
# 022428_91_spaghetti_carbonara.jpg: carbonara (0.98)
# 022405_91_spaghetti_carbonara.jpg: carbonara (0.78)

# %% [markdown]
# Pizza and spaghetti carbonara are recognized almost perfectly.
# Spaghetti bolognese is missing as a class - confused often with carbonara.

# %% [markdown]
# ### Fine-tune model with food101 data
#
# The complete set consists of 750 images for training and 250 images for validation in each of three classes.
#
# Eight models will be trained for each constellation of:
# - two epoch values: 20 and 50,
# - two images sizes: 224 (standard for Yolo) and 512 (images from Hugging Face)
# - two dataset lengths: 75 and 750

# %%
print(PROJECT_PATH / name)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(PROJECT_PATH / name)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
model = YOLO(BASE_MODEL)
#EPOCHS_LIST   = [20, 50]
EPOCHS_LIST   = [50]
#IMG_SIZE_LIST = [224,512]
IMG_SIZE_LIST = [512]
FRACTIONS     = [0.1, 1]
for epochs in EPOCHS_LIST:
    for img in IMG_SIZE_LIST:
        for frac in FRACTIONS:
            name = f"food101_e{epochs}_img{img}_frac{frac}"
            print(f"\n▶️ {name}")
            t0 = time.time()
            res = model.train(
                data=str(DATASET_YAML),
                epochs=epochs,
                imgsz=img,
                batch=BATCH,
                device=DEVICE,
                project=str(PROJECT_PATH),
                name=name,
                exist_ok=True,
                fraction=frac,
                verbose=False
            )
            runtime_min = round((time.time() - t0) / 60, 3)
            (PROJECT_PATH / name / "summary.json").write_text(
                json.dumps({"runtime_min": runtime_min}, ensure_ascii=False)
            )
            print(f"⏱️ runtime: {runtime_min} min")
# Out:
# ▶️ food101_e50_img512_frac0.1
# New https://pypi.org/project/ultralytics/8.3.202 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.201 🚀 Python-3.11.13 torch-2.8.0+cu128 CPU (Intel Xeon Platinum 8370C CPU @ 2.80GHz)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=../data/silver, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=0.1, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=512, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=food101_e50_img512_frac0.1, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=../runs/classify, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/workspaces/marktguru-home-assignment/runs/classify/food101_e50_img512_frac0.1, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=False, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: /workspaces/marktguru-home-assignment/data/silver/train... found 2250 images in 3 classes ✅
# val: /workspaces/marktguru-home-assignment/data/silver/val... found 750 images in 3 classes ✅
# test: None...
# Overriding model.yaml nc=1000 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    334083  ultralytics.nn.modules.head.Classify         [256, 3]
# YOLOv8n-cls summary: 56 layers, 1,442,131 parameters, 1,442,131 gradients, 3.4 GFLOPs
# Transferred 156/158 items from pretrained weights
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 130.2±224.4 MB/s, size: 50.3 KB)
# train: Scanning /workspaces/marktguru-home-assignment/data/silver/train... 225 images, 0 corrupt: 100% ━━━━━━━━━━━━ 225/225 381.5Kit/s 0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 100.0±109.2 MB/s, size: 45.3 KB)
# val: Scanning /workspaces/marktguru-home-assignment/data/silver/val... 750 images, 0 corrupt: 100% ━━━━━━━━━━━━ 750/750 1.3Mit/s 0.0s0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias(decay=0.0)
# Image sizes 512 train, 512 val
# Using 0 dataloader workers
# Logging results to /workspaces/marktguru-home-assignment/runs/classify/food101_e50_img512_frac0.1
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/50         0G     0.6621          1        512: 100% ━━━━━━━━━━━━ 15/15 0.3it/s 46.9s1.2ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 48.0s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/50         0G    0.08859          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 40.9s0.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 45.1s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/50         0G   0.008495          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 40.8s0.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 45.7s2.0ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/50         0G   0.001058          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 42.3s0.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 45.3s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/50         0G   0.000381          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 41.5s0.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 44.9s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/50         0G  0.0001381          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 40.1s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 44.3s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/50         0G  9.429e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 39.9s0.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 44.0s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/50         0G   6.31e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 42.1s0.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 44.3s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/50         0G  4.467e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 40.6s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 43.5s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/50         0G  4.181e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 40.8s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 44.1s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/50         0G   3.34e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 39.6s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 43.2s1.8ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/50         0G  2.955e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 41.3s0.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 44.8s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/50         0G  3.566e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 39.4s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 43.7s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/50         0G  2.994e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 41.3s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 44.1s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/50         0G  2.906e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 40.2s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 43.7s1.8ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/50         0G  3.473e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 39.5s0.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.7it/s 35.5s1.5ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/50         0G  2.969e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 39.0s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 43.0s1.8ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/50         0G  2.449e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 40.4s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 43.0s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/50         0G   2.44e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 39.8s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 43.1s1.8ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/50         0G   2.98e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 40.0s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 42.8s1.8ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       21/50         0G  2.816e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 40.0s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 43.3s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       22/50         0G  2.509e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 40.1s0.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 42.0s1.8ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       23/50         0G  2.728e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 40.5s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 44.3s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       24/50         0G  3.866e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 41.7s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 44.1s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       25/50         0G  2.644e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 40.0s0.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 44.4s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       26/50         0G  2.472e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 41.1s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 43.6s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       27/50         0G  2.762e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 40.6s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 42.7s1.8ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       28/50         0G  1.989e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 38.9s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 43.1s1.8ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       29/50         0G   3.21e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 39.7s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 43.2s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       30/50         0G   2.42e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 40.0s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 43.4s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       31/50         0G  1.955e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 41.5s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 43.5s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       32/50         0G  2.547e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 41.1s0.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 44.1s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       33/50         0G  2.391e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 41.7s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 43.6s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       34/50         0G   2.18e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 40.7s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 44.2s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       35/50         0G  2.047e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 42.3s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 44.4s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       36/50         0G  3.359e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 41.9s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 45.9s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       37/50         0G  1.871e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 42.2s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 45.2s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       38/50         0G  1.751e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 42.5s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 44.1s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       39/50         0G  2.268e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 41.1s0.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 44.3s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       40/50         0G   2.31e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 41.6s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 44.1s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       41/50         0G  2.269e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 41.0s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 43.8s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       42/50         0G  2.463e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 41.2s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 43.8s2.0ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       43/50         0G  2.357e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 42.0s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 44.6s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       44/50         0G  1.656e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 42.3s0.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 44.5s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       45/50         0G  2.224e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 40.8s0.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 44.6s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       46/50         0G  1.744e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 42.4s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 44.3s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       47/50         0G  2.049e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 42.2s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 44.6s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       48/50         0G  3.739e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.3it/s 43.1s0.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 44.5s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       49/50         0G  2.063e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 42.6s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 44.8s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       50/50         0G  2.382e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 41.9s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 44.0s1.9ss
#                    all      0.333          1
#
# 50 epochs completed in 1.183 hours.
# Optimizer stripped from /workspaces/marktguru-home-assignment/runs/classify/food101_e50_img512_frac0.1/weights/last.pt, 3.0MB
# Optimizer stripped from /workspaces/marktguru-home-assignment/runs/classify/food101_e50_img512_frac0.1/weights/best.pt, 3.0MB
#
# Validating /workspaces/marktguru-home-assignment/runs/classify/food101_e50_img512_frac0.1/weights/best.pt...
# Ultralytics 8.3.201 🚀 Python-3.11.13 torch-2.8.0+cu128 CPU (Intel Xeon Platinum 8370C CPU @ 2.80GHz)
# YOLOv8n-cls summary (fused): 30 layers, 1,438,723 parameters, 0 gradients, 3.3 GFLOPs
# train: /workspaces/marktguru-home-assignment/data/silver/train... found 2250 images in 3 classes ✅
# val: /workspaces/marktguru-home-assignment/data/silver/val... found 750 images in 3 classes ✅
# test: None...
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.7it/s 35.6s1.5ss
#                    all      0.333          1
# Speed: 0.0ms preprocess, 39.4ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /workspaces/marktguru-home-assignment/runs/classify/food101_e50_img512_frac0.1
# ⏱️ runtime: 71.703 min
#
# ▶️ food101_e50_img512_frac1
# New https://pypi.org/project/ultralytics/8.3.202 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.201 🚀 Python-3.11.13 torch-2.8.0+cu128 CPU (Intel Xeon Platinum 8370C CPU @ 2.80GHz)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=../data/silver, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=512, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=food101_e50_img512_frac1, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=../runs/classify, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/workspaces/marktguru-home-assignment/runs/classify/food101_e50_img512_frac1, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=False, vid_stride=1, visualize=False, warmup_bias_lr=0.0, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# train: /workspaces/marktguru-home-assignment/data/silver/train... found 2250 images in 3 classes ✅
# val: /workspaces/marktguru-home-assignment/data/silver/val... found 750 images in 3 classes ✅
# test: None...
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    334083  ultralytics.nn.modules.head.Classify         [256, 3]
# YOLOv8n-cls summary: 56 layers, 1,442,131 parameters, 1,442,131 gradients, 3.4 GFLOPs
# Transferred 158/158 items from pretrained weights
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1727.1±686.9 MB/s, size: 50.3 KB)
# train: Scanning /workspaces/marktguru-home-assignment/data/silver/train... 2250 images, 0 corrupt: 100% ━━━━━━━━━━━━ 2250/2250 357.0it/s 6.3s0.4s
# train: New cache created: /workspaces/marktguru-home-assignment/data/silver/train.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2209.9±688.1 MB/s, size: 45.3 KB)
# val: Scanning /workspaces/marktguru-home-assignment/data/silver/val... 750 images, 0 corrupt: 100% ━━━━━━━━━━━━ 750/750 417.6Kit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias(decay=0.0)
# Image sizes 512 train, 512 val
# Using 0 dataloader workers
# Logging results to /workspaces/marktguru-home-assignment/runs/classify/food101_e50_img512_frac1
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/50         0G      2.969         10        512: 100% ━━━━━━━━━━━━ 141/141 0.3it/s 6:472.4ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 43.7s1.9ss
#                    all      0.895          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/50         0G     0.3908         10        512: 100% ━━━━━━━━━━━━ 141/141 0.4it/s 6:412.3ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 42.4s1.8ss
#                    all        0.9          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/50         0G     0.3295         10        512: 100% ━━━━━━━━━━━━ 141/141 0.4it/s 6:422.4ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 44.2s1.9ss
#                    all      0.903          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/50         0G     0.2477         16        512: 85% ━━━━━━━━━━── 120/141 0.3it/s 5:51<1:02

# %% [markdown]
# ### Gather statistics of model training runs

# %%
rows = []
def pick_col(cols, candidates):
    for c in candidates:
        if c in cols: return c
    return None
for run in sorted(PROJECT_PATH.glob("food101_e*_img*_frac*")):
    args_p     = run / "args.yaml"
    results_p  = run / "results.csv"
    summary_p  = run / "summary.json"
    best_pt_p  = run / "weights" / "best.pt"
    if not results_p.exists():
        continue
    args = {}
    if args_p.exists():
        args = yaml.safe_load(args_p.read_text())
    df = pd.read_csv(results_p)
    top1_col = pick_col(df.columns, ["metrics/accuracy_top1", "top1", "val/top1"])
    if top1_col is None:
        best_top1 = float("nan")
    else:
        best_row_idx = df[top1_col].idxmax()
        best_top1 = float(df.loc[best_row_idx, top1_col])
    runtime_min = None
    if summary_p.exists():
        runtime_min = json.loads(summary_p.read_text()).get("runtime_min")
    rows.append({
        "run_dir": str(run.resolve()),
        "epochs": args.get("epochs"),
        "img_size": args.get("imgsz") or args.get("img_size"),
        "fraction": args.get("fraction"),
        "top1_acc_best": round(best_top1, 4) if best_top1 == best_top1 else None,  # NaN guard
        "runtime_min": runtime_min,
        "best_weights": str(best_pt_p.resolve()) if best_pt_p.exists() else None,
    })
stats = pd.DataFrame(rows)
stats_path = PROJECT_PATH / "experiment_stats.csv"
stats.to_csv(stats_path, index=False)
print(f"📄 Saved stats: {stats_path}")
print(stats)
# Out:
# 📄 Saved stats: ../runs/classify/experiment_stats.csv
#                                              run_dir  epochs  img_size  \
# 0  /workspaces/marktguru-home-assignment/runs/cla...      20       224
# 1  /workspaces/marktguru-home-assignment/runs/cla...      20       224
# 2  /workspaces/marktguru-home-assignment/runs/cla...      20       512
# 3  /workspaces/marktguru-home-assignment/runs/cla...      20       512
# 4  /workspaces/marktguru-home-assignment/runs/cla...      50       224
# 5  /workspaces/marktguru-home-assignment/runs/cla...      50       224
# 6  /workspaces/marktguru-home-assignment/runs/cla...      50       512
#
#    fraction  top1_acc_best  runtime_min  \
# 0       0.1         0.3333        6.230
# 1       1.0         0.9720       28.919
# 2       0.1         0.8947       28.893
# 3       1.0         0.9800      158.982
# 4       0.1         0.9173       14.628
# 5       1.0         0.9760       73.864
# 6       0.1         0.9400        0.000
#
#                                         best_weights
# 0  /workspaces/marktguru-home-assignment/runs/cla...
# 1  /workspaces/marktguru-home-assignment/runs/cla...
# 2  /workspaces/marktguru-home-assignment/runs/cla...
# 3  /workspaces/marktguru-home-assignment/runs/cla...
# 4  /workspaces/marktguru-home-assignment/runs/cla...
# 5  /workspaces/marktguru-home-assignment/runs/cla...
# 6  /workspaces/marktguru-home-assignment/runs/cla...

# %% [markdown]
# ### Predict custom uploaded images

# %%
model = YOLO("runs/classify/food101_e20_img224_frac1/weights/best.pt")
model.predict(
    source=Path(DATASET_YAML) / "upload",
    imgsz=224,
    device="cpu",
    save=True,
    project=PROJECT_PATH,
    name="food101_predict_upload"
)
