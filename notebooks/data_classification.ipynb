# %% [markdown]
# ### Import

# %%
import random
import pandas as pd
import time
import json
import yaml
from ultralytics import YOLO
from pathlib import Path

# %% [markdown]
# ### Yolo model parameters
#
# **EPOCHS**: The number of times the entire training dataset is passed through the model during training. More epochs can help the model learn better, but too many can lead to overfitting.
#
# **IMG_SIZE** (image size): The target size (usually width and height in pixels) to which all training and inference images are resized. Larger sizes can improve detection accuracy but use more memory and computation.
#
# **BATCH** (batch size): The number of images the model processes at once before updating its internal parameters. A larger batch size can speed up training (if you have enough GPU memory) but may require more resources.

# %%
DATASET_YAML = Path("../data/silver/")  # point to your dataset.yaml
BASE_MODEL = "yolov8n-cls.pt"
EPOCHS = 50
IMG_SIZE = 512
FRACTION = 1
BATCH = 16
DEVICE = "cpu"
PROJECT_PATH = "../runs/classify"

CLASSES = {
    "pizza": 76,
    "spaghetti_bolognese": 90,
    "spaghetti_carbonara": 91,
}

# %% [markdown]
# ### First run of the pre-trained model

# %%
model = YOLO(BASE_MODEL)
random.seed(42)
N = 8 
subset = []
for cls in CLASSES.keys():
    cls_dir = Path(DATASET_YAML) / "val" / cls
    all_imgs = list(cls_dir.glob("*.jpg"))
    if len(all_imgs) >= N:
        subset.extend(random.sample(all_imgs, N))
    else:
        subset.extend(all_imgs)
results = model.predict(source=subset, imgsz=IMG_SIZE, device=DEVICE, save=True, verbose=False, project=PROJECT_PATH, name="food101_base_model",exist_ok=True)
for r in results:
    fname = Path(r.path).name
    pred_class = r.names[r.probs.top1]
    conf = r.probs.top1conf.item()
    print(f"{fname}: {pred_class} ({conf:.2f})")
# Out:
# Results saved to /workspaces/marktguru-home-assignment/runs/base_model
# 002620_76_pizza.jpg: pizza (0.99)
# 002667_76_pizza.jpg: pizza (0.86)
# 002673_76_pizza.jpg: pizza (1.00)
# 002610_76_pizza.jpg: pizza (0.72)
# 002675_76_pizza.jpg: pizza (0.96)
# 002650_76_pizza.jpg: pizza (0.98)
# 002577_76_pizza.jpg: pizza (0.96)
# 002504_76_pizza.jpg: pizza (0.99)
# 025088_90_spaghetti_bolognese.jpg: crayfish (0.91)
# 025101_90_spaghetti_bolognese.jpg: carbonara (0.38)
# 025187_90_spaghetti_bolognese.jpg: carbonara (0.80)
# 025023_90_spaghetti_bolognese.jpg: plate (0.68)
# 025036_90_spaghetti_bolognese.jpg: plate (0.29)
# 025201_90_spaghetti_bolognese.jpg: carbonara (1.00)
# 025011_90_spaghetti_bolognese.jpg: carbonara (1.00)
# 025068_90_spaghetti_bolognese.jpg: plate (0.50)
# 022289_91_spaghetti_carbonara.jpg: carbonara (0.95)
# 022254_91_spaghetti_carbonara.jpg: carbonara (1.00)
# 022257_91_spaghetti_carbonara.jpg: carbonara (0.99)
# 022410_91_spaghetti_carbonara.jpg: carbonara (1.00)
# 022473_91_spaghetti_carbonara.jpg: carbonara (1.00)
# 022450_91_spaghetti_carbonara.jpg: carbonara (0.98)
# 022428_91_spaghetti_carbonara.jpg: carbonara (0.98)
# 022405_91_spaghetti_carbonara.jpg: carbonara (0.78)

# %% [markdown]
# Pizza and spaghetti carbonara are recognized almost perfectly.
# Spaghetti bolognese is missing as a class - confused often with carbonara.

# %% [markdown]
# ### Fine-tune model with food101 data
#
# The complete set consists of 750 images for training and 250 images for validation in each of three classes.
#
# Eight models will be trained for each constellation of:
# - two epoch values: 20 and 50,
# - two images sizes: 224 (standard for Yolo) and 512 (images from Hugging Face)
# - two dataset lengths: 75 and 750

# %%
model = YOLO(BASE_MODEL)
EPOCHS_LIST   = [20, 50]
IMG_SIZE_LIST = [224,512]
FRACTIONS     = [0.1, 1]
for epochs in EPOCHS_LIST:
    for img in IMG_SIZE_LIST:
        for frac in FRACTIONS:
            name = f"food101_e{epochs}_img{img}_frac{frac}"
            print(f"\n▶️ {name}")
            t0 = time.time()
            res = model.train(
                data=str(DATASET_YAML),
                epochs=epochs,
                imgsz=img,
                batch=BATCH,
                device=DEVICE,
                project=str(PROJECT_PATH),
                name=name,
                exist_ok=True,
                fraction=frac,
                verbose=False
            )
            runtime_min = round((time.time() - t0) / 60, 3)
            (PROJECT_PATH / name / "summary.json").write_text(
                json.dumps({"runtime_min": runtime_min}, ensure_ascii=False)
            )
            print(f"⏱️ runtime: {runtime_min} min")
# Out:
# ▶️ food101_e20_img224_frac0.1
# Ultralytics 8.3.201 🚀 Python-3.11.13 torch-2.8.0+cu128 CPU (Intel Xeon Platinum 8370C CPU @ 2.80GHz)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=../data/silver, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=20, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=0.1, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=food101_e20_img224_frac0.1, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=../runs/classify, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/workspaces/marktguru-home-assignment/runs/classify/food101_e20_img224_frac0.1, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=False, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: /workspaces/marktguru-home-assignment/data/silver/train... found 2250 images in 3 classes ✅
# val: /workspaces/marktguru-home-assignment/data/silver/val... found 750 images in 3 classes ✅
# test: None...
# Overriding model.yaml nc=1000 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    334083  ultralytics.nn.modules.head.Classify         [256, 3]
# YOLOv8n-cls summary: 56 layers, 1,442,131 parameters, 1,442,131 gradients, 3.4 GFLOPs
# Transferred 156/158 items from pretrained weights
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1316.5±548.4 MB/s, size: 50.3 KB)
# train: Scanning /workspaces/marktguru-home-assignment/data/silver/train... 225 images, 0 corrupt: 100% ━━━━━━━━━━━━ 225/225 7.0Kit/s 0.0s
# train: New cache created: /workspaces/marktguru-home-assignment/data/silver/train.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1825.8±516.1 MB/s, size: 45.3 KB)
# val: Scanning /workspaces/marktguru-home-assignment/data/silver/val... 750 images, 0 corrupt: 100% ━━━━━━━━━━━━ 750/750 1.7Mit/s 0.0s0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 0 dataloader workers
# Logging results to /workspaces/marktguru-home-assignment/runs/classify/food101_e20_img224_frac0.1
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/20         0G     0.7023          1        224: 100% ━━━━━━━━━━━━ 15/15 1.7it/s 8.6s1.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.4it/s 10.1s.4s
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/20         0G     0.1274          1        224: 100% ━━━━━━━━━━━━ 15/15 1.6it/s 9.1s1.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.1it/s 11.3s0.7s
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/20         0G    0.01654          1        224: 100% ━━━━━━━━━━━━ 15/15 1.7it/s 9.1s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.4it/s 10.1s.4s
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/20         0G   0.003004          1        224: 100% ━━━━━━━━━━━━ 15/15 1.5it/s 9.9s1.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.3it/s 10.4s0.4s
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/20         0G   0.001097          1        224: 100% ━━━━━━━━━━━━ 15/15 1.6it/s 9.7s1.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.4it/s 10.1s.4s
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/20         0G  0.0005017          1        224: 100% ━━━━━━━━━━━━ 15/15 1.7it/s 9.1s1.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.5it/s 9.5s0.4s
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/20         0G  0.0004209          1        224: 100% ━━━━━━━━━━━━ 15/15 1.7it/s 8.8s1.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.6it/s 9.2s0.4s
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/20         0G  0.0001986          1        224: 100% ━━━━━━━━━━━━ 15/15 1.8it/s 8.4s1.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.6it/s 9.1s0.4s
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/20         0G  0.0001691          1        224: 100% ━━━━━━━━━━━━ 15/15 1.9it/s 8.0s1.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.5it/s 9.5s0.4s
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/20         0G  0.0003015          1        224: 100% ━━━━━━━━━━━━ 15/15 1.7it/s 8.6s1.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.6it/s 9.3s0.4s
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/20         0G  0.0001406          1        224: 100% ━━━━━━━━━━━━ 15/15 1.8it/s 8.2s1.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.6it/s 9.4s0.4s
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/20         0G  0.0001185          1        224: 100% ━━━━━━━━━━━━ 15/15 1.8it/s 8.1s1.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.6it/s 9.3s0.4s
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/20         0G  0.0001048          1        224: 100% ━━━━━━━━━━━━ 15/15 1.8it/s 8.1s1.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.5it/s 9.5s0.4s
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/20         0G  0.0001101          1        224: 100% ━━━━━━━━━━━━ 15/15 1.8it/s 8.4s1.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.6it/s 9.2s0.4s
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/20         0G  9.779e-05          1        224: 100% ━━━━━━━━━━━━ 15/15 1.8it/s 8.3s1.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.6it/s 9.2s0.4s
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/20         0G  0.0001029          1        224: 100% ━━━━━━━━━━━━ 15/15 1.9it/s 8.0s1.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.6it/s 9.2s0.4s
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/20         0G  0.0001176          1        224: 100% ━━━━━━━━━━━━ 15/15 1.9it/s 7.9s1.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.6it/s 9.2s0.4s
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/20         0G  0.0001098          1        224: 100% ━━━━━━━━━━━━ 15/15 1.9it/s 7.9s1.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.6it/s 9.1s0.4s
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/20         0G  9.236e-05          1        224: 100% ━━━━━━━━━━━━ 15/15 1.9it/s 7.9s1.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.6it/s 9.3s0.4s
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/20         0G  0.0001049          1        224: 100% ━━━━━━━━━━━━ 15/15 1.9it/s 7.9s1.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.6it/s 9.2s0.4s
#                    all      0.333          1
#
# 20 epochs completed in 0.101 hours.
# Optimizer stripped from /workspaces/marktguru-home-assignment/runs/classify/food101_e20_img224_frac0.1/weights/last.pt, 3.0MB
# Optimizer stripped from /workspaces/marktguru-home-assignment/runs/classify/food101_e20_img224_frac0.1/weights/best.pt, 3.0MB
#
# Validating /workspaces/marktguru-home-assignment/runs/classify/food101_e20_img224_frac0.1/weights/best.pt...
# Ultralytics 8.3.201 🚀 Python-3.11.13 torch-2.8.0+cu128 CPU (Intel Xeon Platinum 8370C CPU @ 2.80GHz)
# YOLOv8n-cls summary (fused): 30 layers, 1,438,723 parameters, 0 gradients, 3.3 GFLOPs
# train: /workspaces/marktguru-home-assignment/data/silver/train... found 2250 images in 3 classes ✅
# val: /workspaces/marktguru-home-assignment/data/silver/val... found 750 images in 3 classes ✅
# test: None...
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.8it/s 8.7s0.4s
#                    all      0.333          1
# Speed: 0.0ms preprocess, 6.9ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /workspaces/marktguru-home-assignment/runs/classify/food101_e20_img224_frac0.1
# ⏱️ runtime: 6.23 min
#
# ▶️ food101_e20_img224_frac1
# Ultralytics 8.3.201 🚀 Python-3.11.13 torch-2.8.0+cu128 CPU (Intel Xeon Platinum 8370C CPU @ 2.80GHz)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=../data/silver, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=20, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=food101_e20_img224_frac1, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=../runs/classify, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/workspaces/marktguru-home-assignment/runs/classify/food101_e20_img224_frac1, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=False, vid_stride=1, visualize=False, warmup_bias_lr=0.0, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# train: /workspaces/marktguru-home-assignment/data/silver/train... found 2250 images in 3 classes ✅
# val: /workspaces/marktguru-home-assignment/data/silver/val... found 750 images in 3 classes ✅
# test: None...
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    334083  ultralytics.nn.modules.head.Classify         [256, 3]
# YOLOv8n-cls summary: 56 layers, 1,442,131 parameters, 1,442,131 gradients, 3.4 GFLOPs
# Transferred 158/158 items from pretrained weights
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1744.7±760.0 MB/s, size: 50.3 KB)
# train: Scanning /workspaces/marktguru-home-assignment/data/silver/train... 2250 images, 0 corrupt: 100% ━━━━━━━━━━━━ 2250/2250 8.2Kit/s 0.3s0.2s
# train: New cache created: /workspaces/marktguru-home-assignment/data/silver/train.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1376.4±439.5 MB/s, size: 45.3 KB)
# val: Scanning /workspaces/marktguru-home-assignment/data/silver/val... 750 images, 0 corrupt: 100% ━━━━━━━━━━━━ 750/750 1.5Mit/s 0.0s0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 0 dataloader workers
# Logging results to /workspaces/marktguru-home-assignment/runs/classify/food101_e20_img224_frac1
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/20         0G      2.614         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:200.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.6it/s 9.1s0.4s
#                    all      0.907          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/20         0G     0.3648         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:180.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.6it/s 9.4s0.4s
#                    all      0.931          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/20         0G     0.3236         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:180.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.6it/s 9.1s0.4s
#                    all      0.916          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/20         0G     0.2711         10        224: 100% ━━━━━━━━━━━━ 141/141 1.9it/s 1:160.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.7it/s 8.7s0.4s
#                    all      0.927          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/20         0G     0.2463         10        224: 100% ━━━━━━━━━━━━ 141/141 1.9it/s 1:150.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.8it/s 8.6s0.4s
#                    all      0.955          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/20         0G     0.2212         10        224: 100% ━━━━━━━━━━━━ 141/141 1.9it/s 1:150.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.7it/s 9.0s0.4s
#                    all       0.96          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/20         0G     0.1897         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:180.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.6it/s 9.1s0.4s
#                    all      0.951          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/20         0G     0.1829         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:160.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.8it/s 8.7s0.4s
#                    all      0.952          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/20         0G     0.1681         10        224: 100% ━━━━━━━━━━━━ 141/141 1.9it/s 1:160.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.8it/s 8.7s0.4s
#                    all      0.941          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/20         0G     0.1501         10        224: 100% ━━━━━━━━━━━━ 141/141 1.9it/s 1:150.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.7it/s 8.8s0.4s
#                    all      0.953          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/20         0G     0.1383         10        224: 100% ━━━━━━━━━━━━ 141/141 1.9it/s 1:150.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.6it/s 9.2s0.4s
#                    all      0.964          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/20         0G     0.1301         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:180.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.6it/s 9.1s0.4s
#                    all      0.965          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/20         0G     0.1355         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:200.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.6it/s 9.1s0.4s
#                    all      0.967          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/20         0G      0.115         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:200.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.7it/s 8.8s0.4s
#                    all      0.972          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/20         0G    0.08948         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:170.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.4it/s 10.2s0.4s
#                    all      0.964          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/20         0G    0.09355         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:180.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.5it/s 9.5s0.4s
#                    all      0.969          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/20         0G    0.08336         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:160.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.7it/s 8.9s0.4s
#                    all      0.971          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/20         0G    0.07466         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:170.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.6it/s 9.2s0.4s
#                    all      0.968          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/20         0G    0.08596         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:170.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.7it/s 8.9s0.4s
#                    all      0.968          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/20         0G    0.07236         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:170.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.7it/s 8.9s0.4s
#                    all      0.968          1
#
# 20 epochs completed in 0.479 hours.
# Optimizer stripped from /workspaces/marktguru-home-assignment/runs/classify/food101_e20_img224_frac1/weights/last.pt, 3.0MB
# Optimizer stripped from /workspaces/marktguru-home-assignment/runs/classify/food101_e20_img224_frac1/weights/best.pt, 3.0MB
#
# Validating /workspaces/marktguru-home-assignment/runs/classify/food101_e20_img224_frac1/weights/best.pt...
# Ultralytics 8.3.201 🚀 Python-3.11.13 torch-2.8.0+cu128 CPU (Intel Xeon Platinum 8370C CPU @ 2.80GHz)
# YOLOv8n-cls summary (fused): 30 layers, 1,438,723 parameters, 0 gradients, 3.3 GFLOPs
# train: /workspaces/marktguru-home-assignment/data/silver/train... found 2250 images in 3 classes ✅
# val: /workspaces/marktguru-home-assignment/data/silver/val... found 750 images in 3 classes ✅
# test: None...
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.8it/s 8.6s0.4s
#                    all      0.973          1
# Speed: 0.0ms preprocess, 6.7ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /workspaces/marktguru-home-assignment/runs/classify/food101_e20_img224_frac1
# ⏱️ runtime: 28.919 min
#
# ▶️ food101_e20_img512_frac0.1
# Ultralytics 8.3.201 🚀 Python-3.11.13 torch-2.8.0+cu128 CPU (Intel Xeon Platinum 8370C CPU @ 2.80GHz)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=../data/silver, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=20, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=0.1, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=512, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=food101_e20_img512_frac0.1, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=../runs/classify, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/workspaces/marktguru-home-assignment/runs/classify/food101_e20_img512_frac0.1, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=False, vid_stride=1, visualize=False, warmup_bias_lr=0.0, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# train: /workspaces/marktguru-home-assignment/data/silver/train... found 2250 images in 3 classes ✅
# val: /workspaces/marktguru-home-assignment/data/silver/val... found 750 images in 3 classes ✅
# test: None...
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    334083  ultralytics.nn.modules.head.Classify         [256, 3]
# YOLOv8n-cls summary: 56 layers, 1,442,131 parameters, 1,442,131 gradients, 3.4 GFLOPs
# Transferred 158/158 items from pretrained weights
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1295.9±525.5 MB/s, size: 50.3 KB)
# train: Scanning /workspaces/marktguru-home-assignment/data/silver/train... 225 images, 0 corrupt: 100% ━━━━━━━━━━━━ 225/225 6.4Kit/s 0.0s
# train: New cache created: /workspaces/marktguru-home-assignment/data/silver/train.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1510.1±394.6 MB/s, size: 45.3 KB)
# val: Scanning /workspaces/marktguru-home-assignment/data/silver/val... 750 images, 0 corrupt: 100% ━━━━━━━━━━━━ 750/750 1.2Mit/s 0.0s0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias(decay=0.0)
# Image sizes 512 train, 512 val
# Using 0 dataloader workers
# Logging results to /workspaces/marktguru-home-assignment/runs/classify/food101_e20_img512_frac0.1
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/20         0G      2.432          1        512: 100% ━━━━━━━━━━━━ 15/15 0.3it/s 45.5s0.7ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 44.9s1.9ss
#                    all      0.895          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/20         0G     0.4217          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 41.7s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.7it/s 36.8s1.6ss
#                    all      0.769          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/20         0G    0.02674          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 39.6s0.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 43.9s1.9ss
#                    all      0.457          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/20         0G   0.002541          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 41.9s0.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 43.5s1.9ss
#                    all      0.369          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/20         0G  0.0003108          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 41.4s0.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 43.9s1.9ss
#                    all      0.353          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/20         0G   0.000108          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 42.4s0.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 44.6s1.9ss
#                    all      0.341          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/20         0G  0.0001804          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 40.6s0.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 43.8s1.9ss
#                    all      0.335          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/20         0G  5.462e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 42.2s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 43.2s1.9ss
#                    all      0.335          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/20         0G  4.975e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 40.3s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 42.4s1.8ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/20         0G  4.093e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 41.8s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 42.9s1.8ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/20         0G  3.715e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 40.6s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 43.3s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/20         0G   5.52e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 40.9s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 43.9s1.8ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/20         0G  5.308e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 41.2s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 42.9s1.8ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/20         0G  3.482e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 42.5s0.7ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 43.2s1.8ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/20         0G  4.397e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 41.5s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 43.7s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/20         0G  8.481e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 41.5s0.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 43.7s1.9ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/20         0G  3.485e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 41.4s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 43.0s1.8ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/20         0G  0.0002297          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 40.2s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 37.3s1.6ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/20         0G  6.901e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 40.6s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 46.2s2.0ss
#                    all      0.333          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/20         0G  3.213e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.3it/s 43.9s0.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 43.8s1.9ss
#                    all      0.333          1
#
# 20 epochs completed in 0.471 hours.
# Optimizer stripped from /workspaces/marktguru-home-assignment/runs/classify/food101_e20_img512_frac0.1/weights/last.pt, 3.0MB
# Optimizer stripped from /workspaces/marktguru-home-assignment/runs/classify/food101_e20_img512_frac0.1/weights/best.pt, 3.0MB
#
# Validating /workspaces/marktguru-home-assignment/runs/classify/food101_e20_img512_frac0.1/weights/best.pt...
# Ultralytics 8.3.201 🚀 Python-3.11.13 torch-2.8.0+cu128 CPU (Intel Xeon Platinum 8370C CPU @ 2.80GHz)
# YOLOv8n-cls summary (fused): 30 layers, 1,438,723 parameters, 0 gradients, 3.3 GFLOPs
# train: /workspaces/marktguru-home-assignment/data/silver/train... found 2250 images in 3 classes ✅
# val: /workspaces/marktguru-home-assignment/data/silver/val... found 750 images in 3 classes ✅
# test: None...
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 37.3s1.7ss
#                    all      0.893          1
# Speed: 0.0ms preprocess, 41.1ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /workspaces/marktguru-home-assignment/runs/classify/food101_e20_img512_frac0.1
# ⏱️ runtime: 28.893 min
#
# ▶️ food101_e20_img512_frac1
# New https://pypi.org/project/ultralytics/8.3.202 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.201 🚀 Python-3.11.13 torch-2.8.0+cu128 CPU (Intel Xeon Platinum 8370C CPU @ 2.80GHz)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=../data/silver, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=20, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=512, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=food101_e20_img512_frac1, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=../runs/classify, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/workspaces/marktguru-home-assignment/runs/classify/food101_e20_img512_frac1, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=False, vid_stride=1, visualize=False, warmup_bias_lr=0.0, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# train: /workspaces/marktguru-home-assignment/data/silver/train... found 2250 images in 3 classes ✅
# val: /workspaces/marktguru-home-assignment/data/silver/val... found 750 images in 3 classes ✅
# test: None...
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    334083  ultralytics.nn.modules.head.Classify         [256, 3]
# YOLOv8n-cls summary: 56 layers, 1,442,131 parameters, 1,442,131 gradients, 3.4 GFLOPs
# Transferred 158/158 items from pretrained weights
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1676.8±663.5 MB/s, size: 50.3 KB)
# train: Scanning /workspaces/marktguru-home-assignment/data/silver/train... 2250 images, 0 corrupt: 100% ━━━━━━━━━━━━ 2250/2250 6.2Kit/s 0.4s0.1s
# train: New cache created: /workspaces/marktguru-home-assignment/data/silver/train.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1789.0±619.7 MB/s, size: 45.3 KB)
# val: Scanning /workspaces/marktguru-home-assignment/data/silver/val... 750 images, 0 corrupt: 100% ━━━━━━━━━━━━ 750/750 1.1Mit/s 0.0s0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias(decay=0.0)
# Image sizes 512 train, 512 val
# Using 0 dataloader workers
# Logging results to /workspaces/marktguru-home-assignment/runs/classify/food101_e20_img512_frac1
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/20         0G     0.2639         10        512: 100% ━━━━━━━━━━━━ 141/141 0.3it/s 6:492.4ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 44.6s1.9ss
#                    all      0.953          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/20         0G     0.1987         10        512: 100% ━━━━━━━━━━━━ 141/141 0.3it/s 7:112.4ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 41.2s1.8ss
#                    all      0.943          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/20         0G     0.2187         10        512: 100% ━━━━━━━━━━━━ 141/141 0.3it/s 7:112.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 51.0s2.2ss
#                    all      0.968          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/20         0G     0.1893         10        512: 100% ━━━━━━━━━━━━ 141/141 0.3it/s 7:252.4ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 52.2s2.0ss
#                    all      0.953          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/20         0G     0.2081         10        512: 100% ━━━━━━━━━━━━ 141/141 0.3it/s 7:082.4ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 40.5s1.7ss
#                    all      0.944          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/20         0G      0.185         10        512: 100% ━━━━━━━━━━━━ 141/141 0.3it/s 7:312.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 47.6s2.0ss
#                    all      0.961          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/20         0G     0.1405         10        512: 100% ━━━━━━━━━━━━ 141/141 0.3it/s 6:552.4ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 39.9s1.7ss
#                    all      0.964          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/20         0G     0.1254         10        512: 100% ━━━━━━━━━━━━ 141/141 0.3it/s 7:032.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 47.5s2.0ss
#                    all      0.975          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/20         0G     0.1079         10        512: 100% ━━━━━━━━━━━━ 141/141 0.3it/s 6:602.4ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 40.7s1.7ss
#                    all      0.964          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/20         0G     0.1093         10        512: 100% ━━━━━━━━━━━━ 141/141 0.3it/s 6:562.3ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 37.8s1.6ss
#                    all       0.98          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/20         0G    0.09634         10        512: 100% ━━━━━━━━━━━━ 141/141 0.3it/s 7:032.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 42.4s1.8ss
#                    all      0.965          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/20         0G    0.08054         10        512: 100% ━━━━━━━━━━━━ 141/141 0.3it/s 7:202.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 50.9s2.2ss
#                    all      0.969          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/20         0G    0.08389         10        512: 100% ━━━━━━━━━━━━ 141/141 0.3it/s 7:202.9ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 50.7s2.4ss
#                    all      0.965          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/20         0G     0.0675         10        512: 100% ━━━━━━━━━━━━ 141/141 0.3it/s 7:082.3ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 41.3s1.8ss
#                    all      0.973          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/20         0G    0.06164         10        512: 100% ━━━━━━━━━━━━ 141/141 0.3it/s 7:112.4ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 43.1s2.0ss
#                    all      0.971          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/20         0G    0.05494         10        512: 100% ━━━━━━━━━━━━ 141/141 0.3it/s 7:022.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 48.8s2.0ss
#                    all      0.971          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/20         0G    0.04822         10        512: 100% ━━━━━━━━━━━━ 141/141 0.3it/s 7:182.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 47.3s2.0ss
#                    all       0.98          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/20         0G    0.05165         10        512: 100% ━━━━━━━━━━━━ 141/141 0.3it/s 7:132.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 45.2s2.0ss
#                    all      0.977          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/20         0G    0.04889         10        512: 100% ━━━━━━━━━━━━ 141/141 0.3it/s 7:052.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 47.1s2.0ss
#                    all      0.976          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/20         0G    0.05172         10        512: 100% ━━━━━━━━━━━━ 141/141 0.3it/s 7:182.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 46.5s2.1ss
#                    all      0.979          1
#
# 20 epochs completed in 2.638 hours.
# Optimizer stripped from /workspaces/marktguru-home-assignment/runs/classify/food101_e20_img512_frac1/weights/last.pt, 3.0MB
# Optimizer stripped from /workspaces/marktguru-home-assignment/runs/classify/food101_e20_img512_frac1/weights/best.pt, 3.0MB
#
# Validating /workspaces/marktguru-home-assignment/runs/classify/food101_e20_img512_frac1/weights/best.pt...
# Ultralytics 8.3.201 🚀 Python-3.11.13 torch-2.8.0+cu128 CPU (Intel Xeon Platinum 8370C CPU @ 2.80GHz)
# YOLOv8n-cls summary (fused): 30 layers, 1,438,723 parameters, 0 gradients, 3.3 GFLOPs
# train: /workspaces/marktguru-home-assignment/data/silver/train... found 2250 images in 3 classes ✅
# val: /workspaces/marktguru-home-assignment/data/silver/val... found 750 images in 3 classes ✅
# test: None...
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 40.0s1.7ss
#                    all       0.98          1
# Speed: 0.0ms preprocess, 44.2ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /workspaces/marktguru-home-assignment/runs/classify/food101_e20_img512_frac1
# ⏱️ runtime: 158.982 min
#
# ▶️ food101_e50_img224_frac0.1
# New https://pypi.org/project/ultralytics/8.3.202 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.201 🚀 Python-3.11.13 torch-2.8.0+cu128 CPU (Intel Xeon Platinum 8370C CPU @ 2.80GHz)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=../data/silver, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=0.1, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=food101_e50_img224_frac0.1, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=../runs/classify, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/workspaces/marktguru-home-assignment/runs/classify/food101_e50_img224_frac0.1, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=False, vid_stride=1, visualize=False, warmup_bias_lr=0.0, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# train: /workspaces/marktguru-home-assignment/data/silver/train... found 2250 images in 3 classes ✅
# val: /workspaces/marktguru-home-assignment/data/silver/val... found 750 images in 3 classes ✅
# test: None...
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
# ...
#                    all       0.96          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       22/50         0G    0.07383         10        224: 100% ━━━━━━━━━━━━ 141/141 1.9it/s 1:160.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.6it/s 9.1s0.4s
#                    all      0.971          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       23/50         0G    0.07443         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:180.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.7it/s 9.0s0.4s
#                    all      0.972          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       24/50         0G    0.07347         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:170.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.6it/s 9.1s0.4s
#                    all      0.947          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       25/50         0G    0.06184         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:160.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.6it/s 9.3s0.4s
#                    all      0.971          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       26/50         0G    0.06062         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:170.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.7it/s 9.0s0.4s
#                    all      0.967          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       27/50         0G    0.05522         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:180.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.7it/s 8.9s0.4s
#                    all       0.96          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       28/50         0G    0.05535         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:190.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.7it/s 9.0s0.4s
#                    all      0.963          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       29/50         0G    0.06731         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:190.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.5it/s 9.6s0.5s
#                    all      0.963          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       30/50         0G    0.04349         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:170.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.7it/s 8.9s0.4s
#                    all      0.964          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       31/50         0G    0.05258         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:180.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.1it/s 11.3s0.5s
#                    all      0.973          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       32/50         0G    0.04231         10        224: 100% ━━━━━━━━━━━━ 141/141 1.7it/s 1:230.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.8it/s 8.6s0.4s
#                    all      0.972          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       33/50         0G    0.04986         10        224: 100% ━━━━━━━━━━━━ 141/141 1.9it/s 1:150.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.8it/s 8.6s0.4s
#                    all      0.969          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       34/50         0G    0.04002         10        224: 100% ━━━━━━━━━━━━ 141/141 1.9it/s 1:140.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.8it/s 8.5s0.4s
#                    all      0.963          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       35/50         0G     0.0435         10        224: 100% ━━━━━━━━━━━━ 141/141 1.9it/s 1:150.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.8it/s 8.7s0.4s
#                    all      0.971          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       36/50         0G    0.03877         10        224: 100% ━━━━━━━━━━━━ 141/141 1.9it/s 1:160.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.6it/s 9.1s0.4s
#                    all      0.973          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       37/50         0G    0.03341         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:200.6sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.1it/s 11.6s0.5s
#                    all      0.969          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       38/50         0G    0.04149         10        224: 100% ━━━━━━━━━━━━ 141/141 1.7it/s 1:210.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.7it/s 8.9s0.4s
#                    all      0.969          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       39/50         0G    0.04152         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:180.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.7it/s 8.8s0.4s
#                    all      0.972          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       40/50         0G    0.04874         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:170.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.7it/s 8.9s0.4s
#                    all      0.968          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       41/50         0G    0.04354         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:200.6sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.1it/s 11.2s0.5s
#                    all      0.972          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       42/50         0G    0.03307         10        224: 100% ━━━━━━━━━━━━ 141/141 1.7it/s 1:250.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.7it/s 9.0s0.4s
#                    all      0.971          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       43/50         0G    0.02447         10        224: 100% ━━━━━━━━━━━━ 141/141 1.6it/s 1:270.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.6it/s 9.1s0.4s
#                    all      0.973          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       44/50         0G    0.02402         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:170.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.8it/s 8.7s0.4s
#                    all      0.969          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       45/50         0G    0.03165         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:180.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.7it/s 8.8s0.4s
#                    all      0.976          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       46/50         0G    0.03015         10        224: 100% ━━━━━━━━━━━━ 141/141 1.7it/s 1:250.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.7it/s 9.0s0.4s
#                    all      0.975          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       47/50         0G    0.02587         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:170.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.7it/s 8.8s0.4s
#                    all      0.968          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       48/50         0G    0.02179         10        224: 100% ━━━━━━━━━━━━ 141/141 1.9it/s 1:150.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.7it/s 8.9s0.4s
#                    all      0.971          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       49/50         0G    0.02348         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:170.5sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.8it/s 8.7s0.4s
#                    all      0.968          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       50/50         0G    0.02261         10        224: 100% ━━━━━━━━━━━━ 141/141 1.8it/s 1:180.4sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.2it/s 10.7s0.5s
#                    all      0.976          1
#
# 50 epochs completed in 1.227 hours.
# Optimizer stripped from /workspaces/marktguru-home-assignment/runs/classify/food101_e50_img224_frac1/weights/last.pt, 3.0MB
# Optimizer stripped from /workspaces/marktguru-home-assignment/runs/classify/food101_e50_img224_frac1/weights/best.pt, 3.0MB
#
# Validating /workspaces/marktguru-home-assignment/runs/classify/food101_e50_img224_frac1/weights/best.pt...
# Ultralytics 8.3.201 🚀 Python-3.11.13 torch-2.8.0+cu128 CPU (Intel Xeon Platinum 8370C CPU @ 2.80GHz)
# YOLOv8n-cls summary (fused): 30 layers, 1,438,723 parameters, 0 gradients, 3.3 GFLOPs
# train: /workspaces/marktguru-home-assignment/data/silver/train... found 2250 images in 3 classes ✅
# val: /workspaces/marktguru-home-assignment/data/silver/val... found 750 images in 3 classes ✅
# test: None...
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 2.3it/s 10.5s0.5s
#                    all      0.976          1
# Speed: 0.0ms preprocess, 8.7ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /workspaces/marktguru-home-assignment/runs/classify/food101_e50_img224_frac1
# ⏱️ runtime: 73.864 min
#
# ▶️ food101_e50_img512_frac0.1
# New https://pypi.org/project/ultralytics/8.3.202 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.201 🚀 Python-3.11.13 torch-2.8.0+cu128 CPU (Intel Xeon Platinum 8370C CPU @ 2.80GHz)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=../data/silver, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=0.1, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=512, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=food101_e50_img512_frac0.1, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=../runs/classify, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/workspaces/marktguru-home-assignment/runs/classify/food101_e50_img512_frac0.1, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=False, vid_stride=1, visualize=False, warmup_bias_lr=0.0, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# train: /workspaces/marktguru-home-assignment/data/silver/train... found 2250 images in 3 classes ✅
# val: /workspaces/marktguru-home-assignment/data/silver/val... found 750 images in 3 classes ✅
# test: None...
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    334083  ultralytics.nn.modules.head.Classify         [256, 3]
# YOLOv8n-cls summary: 56 layers, 1,442,131 parameters, 1,442,131 gradients, 3.4 GFLOPs
# Transferred 158/158 items from pretrained weights
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1569.4±649.0 MB/s, size: 50.3 KB)
# train: Scanning /workspaces/marktguru-home-assignment/data/silver/train... 225 images, 0 corrupt: 100% ━━━━━━━━━━━━ 225/225 8.5Kit/s 0.0s
# train: New cache created: /workspaces/marktguru-home-assignment/data/silver/train.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1465.4±577.5 MB/s, size: 45.3 KB)
# val: Scanning /workspaces/marktguru-home-assignment/data/silver/val... 750 images, 0 corrupt: 100% ━━━━━━━━━━━━ 750/750 1.2Mit/s 0.0s0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias(decay=0.0)
# Image sizes 512 train, 512 val
# Using 0 dataloader workers
# Logging results to /workspaces/marktguru-home-assignment/runs/classify/food101_e50_img512_frac0.1
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/50         0G      2.511          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 42.7s0.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.6it/s 43.4s1.9ss
#                    all       0.94          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/50         0G     0.2684          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 42.0s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 47.5s2.0ss
#                    all      0.919          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/50         0G   0.005306          1        512: 100% ━━━━━━━━━━━━ 15/15 0.3it/s 45.0s0.8ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 45.5s1.8ss
#                    all      0.713          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/50         0G    0.00167          1        512: 100% ━━━━━━━━━━━━ 15/15 0.3it/s 44.9s0.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 45.4s1.9ss
#                    all      0.541          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/50         0G   6.63e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.4it/s 42.0s0.6ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 45.9s1.8ss
#                    all      0.468          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/50         0G  3.096e-05          1        512: 100% ━━━━━━━━━━━━ 15/15 0.3it/s 44.8s0.5ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 0.5it/s 44.6s1.9ss
#                    all      0.408          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/50         0G  9.613e-05         16        512: 47% ━━━━━╸────── 7/15 0.3it/s 24.4s<26.6s

# %% [markdown]
# ### Gather statistics of model training runs

# %%
rows = []
def pick_col(cols, candidates):
    for c in candidates:
        if c in cols: return c
    return None
for run in sorted(PROJECT_PATH.glob("food101_e*_img*_frac*")):
    args_p     = run / "args.yaml"
    results_p  = run / "results.csv"
    summary_p  = run / "summary.json"
    best_pt_p  = run / "weights" / "best.pt"
    if not results_p.exists():
        continue
    args = {}
    if args_p.exists():
        args = yaml.safe_load(args_p.read_text())
    df = pd.read_csv(results_p)
    top1_col = pick_col(df.columns, ["metrics/accuracy_top1", "top1", "val/top1"])
    if top1_col is None:
        best_top1 = float("nan")
    else:
        best_row_idx = df[top1_col].idxmax()
        best_top1 = float(df.loc[best_row_idx, top1_col])
    runtime_min = None
    if summary_p.exists():
        runtime_min = json.loads(summary_p.read_text()).get("runtime_min")
    rows.append({
        "run_dir": str(run.resolve()),
        "epochs": args.get("epochs"),
        "img_size": args.get("imgsz") or args.get("img_size"),
        "fraction": args.get("fraction"),
        "top1_acc_best": round(best_top1, 4) if best_top1 == best_top1 else None,  # NaN guard
        "runtime_min": runtime_min,
        "best_weights": str(best_pt_p.resolve()) if best_pt_p.exists() else None,
    })
stats = pd.DataFrame(rows)
stats_path = PROJECT_PATH / "experiment_stats.csv"
stats.to_csv(stats_path, index=False)
print(f"📄 Saved stats: {stats_path}")
print(stats)
# Out:
# 📄 Saved stats: ../runs/experiment_stats.csv
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Predict custom uploaded images

# %%
model = YOLO("runs/classify/food101_e20_img224_frac1/weights/best.pt")
model.predict(
    source=Path(DATASET_YAML) / "upload",
    imgsz=224,
    device="cpu",
    save=True,
    project=PROJECT_PATH,
    name="food101_predict_upload"
)
